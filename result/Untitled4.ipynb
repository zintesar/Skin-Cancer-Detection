# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt

CATEGORIES = ["malignant","benign"]

def prepare(filepath):
    IMG_SIZE = 128
    img_array = cv2.imread(filepath,cv2.IMREAD_GRAYSCALE)
    image_array = img_array
    new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
    plt.imshow(new_array, cmap='gray')  
    plt.show() 
    return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,1)

model = tf.keras.models.load_model("skincan_cnn.model")

j=6
prediction = model.predict([prepare(f"C:/Users/alu/Desktop/final thes2/cnn_f/test2/malignant/m ({j}).jpg")])
#print(CATEGORIES[int(prediction[0][0])])
print(f"Given Image No is {j} & The Prediction is {CATEGORIES[int(prediction[0][0])]}")

#for i in range(1,51):
    
    #prediction = model.predict([prepare(f"C:/Users/alu/Desktop/final thes2/cnn_f/test/malignant/m ({i}).jpg")])
    #print(f"Given Image No is {i} & The Prediction is {CATEGORIES[int(prediction[0][0])]}")
    #print(CATEGORIES[int(prediction[0][0])])
# Out:
# Given Image No is 6 & The Prediction is malignant
